# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import random 
import numpy as np
import requests
import json 
import datetime
import time
from api_keys import api_key
from citipy import citipy
from pprint import pprint

output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 640

# %%
#Randomly generate latitude and longitude numbers. lookup nearest city using citipy

randCity = []
randCountry = []
loopcnt = 0

#Loop through until at least 500 unique (non-repeat) city names are found

while len(randCity) < 600 :
    
    loopcnt +=1
    
    # Randomly generate latitude
    lat_pos = random.randint(0,2)
    base_lat = random.randint(0,91)
    dec_lat = random.random()/100
    lat = base_lat + dec_lat
    
    if lat_pos == 1:
        lat = lat * -1
    
    # Randomly generate longitude
    lng_pos = random.randint(0,2)
    base_lng = random.randint(0,181)
    dec_lng = random.random()/100
    lng = base_lng + dec_lng
    
    if lng_pos == 1:
        lng = lng * -1
         
    
    # Call citipy file to get nearest city based on random lat and lng
    city = citipy.nearest_city(lat, lng)
    
    # Test to see if the random city is already in the list, if not, add it to the city and country lists
    foundCity = False
    
    for j in range(len(randCity)):
        if city.city_name == randCity[j]:
            foundCity = True
            
    if foundCity==False  :   
        randCity.append(city.city_name)
        randCountry.append(city.country_code)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=b92b1e72d600408724344690fb8e3399&units=imperial&q=

# %%
# Loop through the list of cities and perform request for data on each
search_data = []
cityList = []
countryList = []

x = 0
print("Beginning Data Retrieval  ")
print("-------------------------------")

for city in randCity:
    x += 1
    print(f"Processing record {x} of Set 1 | {city}")   
    response = requests.get(query_url + city).json()
    searchCityID = response.get("id")
    
    if response.get("id"):      
        search_data.append(response)
        cityList.append(city)
        countryList.append(randCountry[x-1])
    else:
        print(f"{city} not found. Skipping...")
          
print("-------------------------------")
print("Data Retrieval Complete ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing record 1 of Set 1 | ostrogozhsk
# Processing record 2 of Set 1 | alofi
# Processing record 3 of Set 1 | aleksandrov gay
# Processing record 4 of Set 1 | leningradskiy
# Processing record 5 of Set 1 | butaritari
# Processing record 6 of Set 1 | qaanaaq
# Processing record 7 of Set 1 | georgetown
# Processing record 8 of Set 1 | carnarvon
# Processing record 9 of Set 1 | dikson
# Processing record 10 of Set 1 | talnakh
# Processing record 11 of Set 1 | manakara
# Processing record 12 of Set 1 | khatanga
# Processing record 13 of Set 1 | khonuu
# khonuu not found. Skipping...
# Processing record 14 of Set 1 | darbhanga
# Processing record 15 of Set 1 | barrow
# Processing record 16 of Set 1 | inhambane
# Processing record 17 of Set 1 | tiksi
# Processing record 18 of Set 1 | dolbeau
# dolbeau not found. Skipping...
# Processing record 19 of Set 1 | amga
# Processing record 20 of Set 1 | olafsvik
# olafsvik not found. Skipping...
# Processing record 21 of Set 1 | muros
# Processing record 22 of Set 1 | pahrump
# Processing record 23 of Set 1 | san juan
# Processing record 24 of Set 1 | abu dhabi
# Processing record 25 of Set 1 | riyadh
# Processing record 26 of Set 1 | hithadhoo
# Processing record 27 of Set 1 | tura
# Processing record 28 of Set 1 | kapaa
# Processing record 29 of Set 1 | san jeronimo
# Processing record 30 of Set 1 | vaini
# Processing record 31 of Set 1 | hermanus
# Processing record 32 of Set 1 | vilhena
# Processing record 33 of Set 1 | mandalgovi
# Processing record 34 of Set 1 | rikitea
# Processing record 35 of Set 1 | sur
# Processing record 36 of Set 1 | punta arenas
# Processing record 37 of Set 1 | longyearbyen
# Processing record 38 of Set 1 | tuktoyaktuk
# Processing record 39 of Set 1 | kayerkan
# Processing record 40 of Set 1 | attawapiskat
# attawapiskat not found. Skipping...
# Processing record 41 of Set 1 | mataura
# Processing record 42 of Set 1 | geraldton
# Processing record 43 of Set 1 | zhangye
# Processing record 44 of Set 1 | waw
# waw not found. Skipping...
# Processing record 45 of Set 1 | port alfred
# Processing record 46 of Set 1 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing record 47 of Set 1 | tahoua
# Processing record 48 of Set 1 | bandarbeyla
# Processing record 49 of Set 1 | mori
# Processing record 50 of Set 1 | belaya gora
# Processing record 51 of Set 1 | pevek
# Processing record 52 of Set 1 | sao jose da coroa grande
# Processing record 53 of Set 1 | savannah bight
# Processing record 54 of Set 1 | umm lajj
# Processing record 55 of Set 1 | sri aman
# Processing record 56 of Set 1 | formoso do araguaia
# formoso do araguaia not found. Skipping...
# Processing record 57 of Set 1 | saskylakh
# Processing record 58 of Set 1 | kolosovka
# Processing record 59 of Set 1 | jamestown
# Processing record 60 of Set 1 | luderitz
# Processing record 61 of Set 1 | narsaq
# Processing record 62 of Set 1 | hobart
# Processing record 63 of Set 1 | whitehorse
# Processing record 64 of Set 1 | vardo
# Processing record 65 of Set 1 | cherskiy
# Processing record 66 of Set 1 | east london
# Processing record 67 of Set 1 | nakhon thai
# Processing record 68 of Set 1 | alihe
# Processing record 69 of Set 1 | lata
# Processing record 70 of Set 1 | hasaki
# Processing record 71 of Set 1 | saint-philippe
# Processing record 72 of Set 1 | wattegama
# Processing record 73 of Set 1 | ribeira grande
# Processing record 74 of Set 1 | bom jardim
# Processing record 75 of Set 1 | yekaterinoslavka
# Processing record 76 of Set 1 | batangafo
# Processing record 77 of Set 1 | barentsburg
# barentsburg not found. Skipping...
# Processing record 78 of Set 1 | ushuaia
# Processing record 79 of Set 1 | zhezkazgan
# Processing record 80 of Set 1 | aykhal
# Processing record 81 of Set 1 | mason city
# Processing record 82 of Set 1 | bluff
# Processing record 83 of Set 1 | taolanaro
# taolanaro not found. Skipping...
# Processing record 84 of Set 1 | roebourne
# Processing record 85 of Set 1 | tasiilaq
# Processing record 86 of Set 1 | nikolskoye
# Processing record 87 of Set 1 | mys shmidta
# mys shmidta not found. Skipping...
# Processing record 88 of Set 1 | maragogi
# Processing record 89 of Set 1 | changchun
# Processing record 90 of Set 1 | takoradi
# Processing record 91 of Set 1 | turbat
# Processing record 92 of Set 1 | mahebourg
# Processing record 93 of Set 1 | panguna
# Processing record 94 of Set 1 | tandlianwala
# Processing record 95 of Set 1 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing record 96 of Set 1 | scottsburgh
# scottsburgh not found. Skipping...
# Processing record 97 of Set 1 | bengkulu
# bengkulu not found. Skipping...
# Processing record 98 of Set 1 | codrington
# Processing record 99 of Set 1 | bambous virieux
# Processing record 100 of Set 1 | mount gambier
# Processing record 101 of Set 1 | cidreira
# Processing record 102 of Set 1 | folldal
# Processing record 103 of Set 1 | belushya guba
# belushya guba not found. Skipping...
# Processing record 104 of Set 1 | vikindu
# Processing record 105 of Set 1 | albany
# Processing record 106 of Set 1 | atuona
# Processing record 107 of Set 1 | svetlogorsk
# Processing record 108 of Set 1 | ingham
# Processing record 109 of Set 1 | manbij
# Processing record 110 of Set 1 | zilupe
# Processing record 111 of Set 1 | sjovegan
# Processing record 112 of Set 1 | rungata
# rungata not found. Skipping...
# Processing record 113 of Set 1 | sabla
# Processing record 114 of Set 1 | port elizabeth
# Processing record 115 of Set 1 | beringovskiy
# Processing record 116 of Set 1 | sirsa
# Processing record 117 of Set 1 | bang len
# Processing record 118 of Set 1 | laguna
# Processing record 119 of Set 1 | batagay
# Processing record 120 of Set 1 | manokwari
# Processing record 121 of Set 1 | moranbah
# Processing record 122 of Set 1 | koumac
# Processing record 123 of Set 1 | busselton
# Processing record 124 of Set 1 | gorele
# Processing record 125 of Set 1 | faanui
# Processing record 126 of Set 1 | khor
# Processing record 127 of Set 1 | kodiak
# Processing record 128 of Set 1 | bredasdorp
# Processing record 129 of Set 1 | upernavik
# Processing record 130 of Set 1 | grand river south east
# grand river south east not found. Skipping...
# Processing record 131 of Set 1 | klaksvik
# Processing record 132 of Set 1 | haines junction
# Processing record 133 of Set 1 | balkhash
# Processing record 134 of Set 1 | lavrentiya
# Processing record 135 of Set 1 | cockburn town
# Processing record 136 of Set 1 | bethel
# Processing record 137 of Set 1 | amderma
# amderma not found. Skipping...
# Processing record 138 of Set 1 | airai
# Processing record 139 of Set 1 | irara
# Processing record 140 of Set 1 | hilo
# Processing record 141 of Set 1 | victoria
# Processing record 142 of Set 1 | tuatapere
# Processing record 143 of Set 1 | alice springs
# Processing record 144 of Set 1 | chuy
# Processing record 145 of Set 1 | yellowknife
# Processing record 146 of Set 1 | nsanje
# Processing record 147 of Set 1 | pa sang
# Processing record 148 of Set 1 | salalah
# Processing record 149 of Set 1 | tsihombe
# tsihombe not found. Skipping...
# Processing record 150 of Set 1 | dwarka
# Processing record 151 of Set 1 | vaitupu
# vaitupu not found. Skipping...
# Processing record 152 of Set 1 | buala
# Processing record 153 of Set 1 | chokurdakh
# Processing record 154 of Set 1 | khani
# Processing record 155 of Set 1 | el alto
# Processing record 156 of Set 1 | innisfail
# Processing record 157 of Set 1 | sakakah
# sakakah not found. Skipping...
# Processing record 158 of Set 1 | balabac
# Processing record 159 of Set 1 | borodino
# Processing record 160 of Set 1 | misratah
# Processing record 161 of Set 1 | dinguiraye
# Processing record 162 of Set 1 | basudebpur
# Processing record 163 of Set 1 | tiznit
# Processing record 164 of Set 1 | tulagi
# tulagi not found. Skipping...
# Processing record 165 of Set 1 | gamba
# Processing record 166 of Set 1 | adrar
# Processing record 167 of Set 1 | goure
# Processing record 168 of Set 1 | la ronge
# Processing record 169 of Set 1 | kamiiso
# Processing record 170 of Set 1 | sistranda
# Processing record 171 of Set 1 | torbay
# Processing record 172 of Set 1 | pastavy
# Processing record 173 of Set 1 | hun
# Processing record 174 of Set 1 | bereda
# Processing record 175 of Set 1 | xudat
# Processing record 176 of Set 1 | menongue
# Processing record 177 of Set 1 | sobolevo
# Processing record 178 of Set 1 | jiddah
# jiddah not found. Skipping...
# Processing record 179 of Set 1 | buariki
# buariki not found. Skipping...
# Processing record 180 of Set 1 | touros
# Processing record 181 of Set 1 | mokrousovo
# Processing record 182 of Set 1 | new norfolk
# Processing record 183 of Set 1 | severo-kurilsk
# Processing record 184 of Set 1 | karakol
# Processing record 185 of Set 1 | dalby
# Processing record 186 of Set 1 | husavik
# Processing record 187 of Set 1 | iqaluit
# Processing record 188 of Set 1 | hamilton
# Processing record 189 of Set 1 | kawhia
# Processing record 190 of Set 1 | kavieng
# Processing record 191 of Set 1 | tongchuan
# Processing record 192 of Set 1 | dingle
# Processing record 193 of Set 1 | zhigansk
# Processing record 194 of Set 1 | manaus
# Processing record 195 of Set 1 | ajdabiya
# Processing record 196 of Set 1 | tabiauea
# tabiauea not found. Skipping...
# Processing record 197 of Set 1 | chapais
# Processing record 198 of Set 1 | tongren
# Processing record 199 of Set 1 | dzerzhinsk
# Processing record 200 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing record 201 of Set 1 | pleshanovo
# Processing record 202 of Set 1 | kirakira
# Processing record 203 of Set 1 | riga
# Processing record 204 of Set 1 | mogadishu
# Processing record 205 of Set 1 | cabo san lucas
# Processing record 206 of Set 1 | yulara
# Processing record 207 of Set 1 | tanshui
# tanshui not found. Skipping...
# Processing record 208 of Set 1 | mundgod
# Processing record 209 of Set 1 | nguruka
# Processing record 210 of Set 1 | port blair
# Processing record 211 of Set 1 | souillac
# Processing record 212 of Set 1 | port moresby
# Processing record 213 of Set 1 | ust-nera
# Processing record 214 of Set 1 | pokhara
# Processing record 215 of Set 1 | fort-shevchenko
# Processing record 216 of Set 1 | ashford
# Processing record 217 of Set 1 | waraseoni
# Processing record 218 of Set 1 | grindavik
# Processing record 219 of Set 1 | fort nelson
# Processing record 220 of Set 1 | lorengau
# Processing record 221 of Set 1 | kegayli
# kegayli not found. Skipping...
# Processing record 222 of Set 1 | meylan
# Processing record 223 of Set 1 | port hardy
# Processing record 224 of Set 1 | yar-sale
# Processing record 225 of Set 1 | te anau
# Processing record 226 of Set 1 | puerto carreno
# Processing record 227 of Set 1 | acajutla
# Processing record 228 of Set 1 | komsomolskiy
# Processing record 229 of Set 1 | viseu
# Processing record 230 of Set 1 | tilichiki
# Processing record 231 of Set 1 | cape town
# Processing record 232 of Set 1 | businga
# Processing record 233 of Set 1 | puerto ayora
# Processing record 234 of Set 1 | pucallpa
# Processing record 235 of Set 1 | avarua
# Processing record 236 of Set 1 | dalneye konstantinovo
# dalneye konstantinovo not found. Skipping...
# Processing record 237 of Set 1 | savantvadi
# Processing record 238 of Set 1 | safaga
# safaga not found. Skipping...
# Processing record 239 of Set 1 | kariba
# Processing record 240 of Set 1 | aksarka
# Processing record 241 of Set 1 | pala
# Processing record 242 of Set 1 | skagen
# Processing record 243 of Set 1 | kloulklubed
# Processing record 244 of Set 1 | saint-joseph
# Processing record 245 of Set 1 | nata
# Processing record 246 of Set 1 | kargil
# Processing record 247 of Set 1 | spearfish
# Processing record 248 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 249 of Set 1 | vao
# Processing record 250 of Set 1 | chumikan
# Processing record 251 of Set 1 | kaspiyskiy
# Processing record 252 of Set 1 | vaitape
# Processing record 253 of Set 1 | kahului
# Processing record 254 of Set 1 | srirampur
# Processing record 255 of Set 1 | clyde river
# Processing record 256 of Set 1 | ust-kamchatsk
# ust-kamchatsk not found. Skipping...
# Processing record 257 of Set 1 | cabra
# Processing record 258 of Set 1 | seoul
# Processing record 259 of Set 1 | szentlorinc
# Processing record 260 of Set 1 | kaitangata
# Processing record 261 of Set 1 | salym
# Processing record 262 of Set 1 | lagoa
# Processing record 263 of Set 1 | ambon
# Processing record 264 of Set 1 | qandala
# Processing record 265 of Set 1 | bonavista
# Processing record 266 of Set 1 | celestun
# Processing record 267 of Set 1 | walvis bay
# Processing record 268 of Set 1 | hobyo
# Processing record 269 of Set 1 | vila do maio
# Processing record 270 of Set 1 | calmar
# Processing record 271 of Set 1 | mazatlan
# Processing record 272 of Set 1 | broome
# Processing record 273 of Set 1 | kamenskoye
# kamenskoye not found. Skipping...
# Processing record 274 of Set 1 | san cristobal
# Processing record 275 of Set 1 | ajaccio
# Processing record 276 of Set 1 | healdsburg
# Processing record 277 of Set 1 | vostok
# Processing record 278 of Set 1 | tabou
# Processing record 279 of Set 1 | luba
# Processing record 280 of Set 1 | talah
# talah not found. Skipping...
# Processing record 281 of Set 1 | serebryansk
# Processing record 282 of Set 1 | auki
# Processing record 283 of Set 1 | kamenka
# Processing record 284 of Set 1 | strezhevoy
# Processing record 285 of Set 1 | sao geraldo do araguaia
# Processing record 286 of Set 1 | tiruchchendur
# Processing record 287 of Set 1 | yenagoa
# Processing record 288 of Set 1 | ketchikan
# Processing record 289 of Set 1 | hakkari
# Processing record 290 of Set 1 | hofn
# Processing record 291 of Set 1 | tamworth
# Processing record 292 of Set 1 | nanortalik
# Processing record 293 of Set 1 | shubarkuduk
# Processing record 294 of Set 1 | saint george
# Processing record 295 of Set 1 | faya
# Processing record 296 of Set 1 | naze
# Processing record 297 of Set 1 | bossembele
# bossembele not found. Skipping...
# Processing record 298 of Set 1 | cockenzie
# Processing record 299 of Set 1 | homer
# Processing record 300 of Set 1 | azrow
# azrow not found. Skipping...
# Processing record 301 of Set 1 | katsuura
# Processing record 302 of Set 1 | yeletskiy
# yeletskiy not found. Skipping...
# Processing record 303 of Set 1 | berlevag
# Processing record 304 of Set 1 | oskarshamn
# Processing record 305 of Set 1 | rapar
# Processing record 306 of Set 1 | norman wells
# Processing record 307 of Set 1 | sindor
# Processing record 308 of Set 1 | yerbogachen
# Processing record 309 of Set 1 | agva
# agva not found. Skipping...
# Processing record 310 of Set 1 | kununurra
# Processing record 311 of Set 1 | provideniya
# Processing record 312 of Set 1 | mahadday weyne
# mahadday weyne not found. Skipping...
# Processing record 313 of Set 1 | babanusah
# babanusah not found. Skipping...
# Processing record 314 of Set 1 | biak
# Processing record 315 of Set 1 | poum
# Processing record 316 of Set 1 | meulaboh
# Processing record 317 of Set 1 | skjervoy
# Processing record 318 of Set 1 | paamiut
# Processing record 319 of Set 1 | kupang
# Processing record 320 of Set 1 | tumannyy
# tumannyy not found. Skipping...
# Processing record 321 of Set 1 | los llanos de aridane
# Processing record 322 of Set 1 | nemuro
# Processing record 323 of Set 1 | gushikawa
# Processing record 324 of Set 1 | cap-haitien
# Processing record 325 of Set 1 | agadez
# Processing record 326 of Set 1 | gigmoto
# Processing record 327 of Set 1 | marienburg
# Processing record 328 of Set 1 | evensk
# Processing record 329 of Set 1 | marsh harbour
# Processing record 330 of Set 1 | dukat
# Processing record 331 of Set 1 | gardan diwal
# gardan diwal not found. Skipping...
# Processing record 332 of Set 1 | bolsheustikinskoye
# bolsheustikinskoye not found. Skipping...
# Processing record 333 of Set 1 | talcahuano
# Processing record 334 of Set 1 | key west
# Processing record 335 of Set 1 | mendeleyevo
# Processing record 336 of Set 1 | semnan
# Processing record 337 of Set 1 | thompson
# Processing record 338 of Set 1 | znamenskoye
# Processing record 339 of Set 1 | kavaratti
# Processing record 340 of Set 1 | bubaque
# Processing record 341 of Set 1 | dakar
# Processing record 342 of Set 1 | matara
# Processing record 343 of Set 1 | ancud
# Processing record 344 of Set 1 | kristinehamn
# Processing record 345 of Set 1 | talara
# Processing record 346 of Set 1 | preobrazheniye
# Processing record 347 of Set 1 | guerrero negro
# Processing record 348 of Set 1 | tomohon
# Processing record 349 of Set 1 | mackenzie
# Processing record 350 of Set 1 | yanan
# yanan not found. Skipping...
# Processing record 351 of Set 1 | viedma
# Processing record 352 of Set 1 | santa eulalia del rio
# santa eulalia del rio not found. Skipping...
# Processing record 353 of Set 1 | galiwinku
# galiwinku not found. Skipping...
# Processing record 354 of Set 1 | mount isa
# Processing record 355 of Set 1 | high level
# Processing record 356 of Set 1 | ust-ilimsk
# Processing record 357 of Set 1 | moose factory
# Processing record 358 of Set 1 | bosaso
# Processing record 359 of Set 1 | mildura
# Processing record 360 of Set 1 | ravar
# Processing record 361 of Set 1 | saldanha
# Processing record 362 of Set 1 | jiroft
# jiroft not found. Skipping...
# Processing record 363 of Set 1 | alanya
# Processing record 364 of Set 1 | kemijarvi
# kemijarvi not found. Skipping...
# Processing record 365 of Set 1 | bur gabo
# bur gabo not found. Skipping...
# Processing record 366 of Set 1 | ishlei
# ishlei not found. Skipping...
# Processing record 367 of Set 1 | nantucket
# Processing record 368 of Set 1 | myitkyina
# Processing record 369 of Set 1 | gerash
# Processing record 370 of Set 1 | picton
# Processing record 371 of Set 1 | nalut
# Processing record 372 of Set 1 | shimoda
# Processing record 373 of Set 1 | ilulissat
# Processing record 374 of Set 1 | oranjemund
# Processing record 375 of Set 1 | shakhrinau
# shakhrinau not found. Skipping...
# Processing record 376 of Set 1 | salme
# Processing record 377 of Set 1 | mullaitivu
# mullaitivu not found. Skipping...
# Processing record 378 of Set 1 | bara
# Processing record 379 of Set 1 | umzimvubu
# umzimvubu not found. Skipping...
# Processing record 380 of Set 1 | thoen
# Processing record 381 of Set 1 | neuquen
# Processing record 382 of Set 1 | skibotn
# Processing record 383 of Set 1 | kanniyakumari
# Processing record 384 of Set 1 | eldikan
# eldikan not found. Skipping...
# Processing record 385 of Set 1 | zakamensk
# Processing record 386 of Set 1 | hovd
# Processing record 387 of Set 1 | constantine
# Processing record 388 of Set 1 | urubamba
# Processing record 389 of Set 1 | carutapera
# Processing record 390 of Set 1 | kenai
# Processing record 391 of Set 1 | goderich
# Processing record 392 of Set 1 | padang
# Processing record 393 of Set 1 | portland
# Processing record 394 of Set 1 | ust-koksa
# Processing record 395 of Set 1 | almaznyy
# Processing record 396 of Set 1 | caramay
# Processing record 397 of Set 1 | general roca
# Processing record 398 of Set 1 | srednekolymsk
# Processing record 399 of Set 1 | tautira
# Processing record 400 of Set 1 | kaoma
# Processing record 401 of Set 1 | oistins
# Processing record 402 of Set 1 | esperance
# Processing record 403 of Set 1 | zubtsov
# Processing record 404 of Set 1 | saleaula
# saleaula not found. Skipping...
# Processing record 405 of Set 1 | verkhoturye
# Processing record 406 of Set 1 | volchansk
# Processing record 407 of Set 1 | rehoboth
# Processing record 408 of Set 1 | bilma
# Processing record 409 of Set 1 | shingu
# Processing record 410 of Set 1 | lang suan
# Processing record 411 of Set 1 | namtsy
# Processing record 412 of Set 1 | limulunga
# Processing record 413 of Set 1 | ilhabela
# Processing record 414 of Set 1 | fortuna
# Processing record 415 of Set 1 | barbar
# barbar not found. Skipping...
# Processing record 416 of Set 1 | arraial do cabo
# Processing record 417 of Set 1 | hambantota
# Processing record 418 of Set 1 | grand gaube
# Processing record 419 of Set 1 | balkanabat
# Processing record 420 of Set 1 | bacolod
# Processing record 421 of Set 1 | aklavik
# Processing record 422 of Set 1 | leshukonskoye
# Processing record 423 of Set 1 | south yuba city
# Processing record 424 of Set 1 | richards bay
# Processing record 425 of Set 1 | qasigiannguit
# Processing record 426 of Set 1 | det udom
# Processing record 427 of Set 1 | castro
# Processing record 428 of Set 1 | chiusi
# Processing record 429 of Set 1 | sumbawa
# sumbawa not found. Skipping...
# Processing record 430 of Set 1 | bayog
# Processing record 431 of Set 1 | mana
# Processing record 432 of Set 1 | novikovo
# Processing record 433 of Set 1 | bilibino
# Processing record 434 of Set 1 | kurilsk
# Processing record 435 of Set 1 | tabuk
# Processing record 436 of Set 1 | sofiyivka
# Processing record 437 of Set 1 | moscow
# Processing record 438 of Set 1 | linxia
# Processing record 439 of Set 1 | pacific grove
# Processing record 440 of Set 1 | samarai
# Processing record 441 of Set 1 | omsukchan
# Processing record 442 of Set 1 | erzin
# Processing record 443 of Set 1 | lebu
# Processing record 444 of Set 1 | maun
# Processing record 445 of Set 1 | narbonne
# Processing record 446 of Set 1 | tarudant
# tarudant not found. Skipping...
# Processing record 447 of Set 1 | latung
# Processing record 448 of Set 1 | sambava
# Processing record 449 of Set 1 | muroto
# Processing record 450 of Set 1 | waipawa
# Processing record 451 of Set 1 | caravelas
# Processing record 452 of Set 1 | syedove
# Processing record 453 of Set 1 | bakhmach
# Processing record 454 of Set 1 | aquiraz
# Processing record 455 of Set 1 | jablanica
# Processing record 456 of Set 1 | amapa
# Processing record 457 of Set 1 | mecca
# Processing record 458 of Set 1 | andenes
# andenes not found. Skipping...
# Processing record 459 of Set 1 | saint-augustin
# Processing record 460 of Set 1 | bafra
# bafra not found. Skipping...
# Processing record 461 of Set 1 | takob
# takob not found. Skipping...
# Processing record 462 of Set 1 | palauig
# Processing record 463 of Set 1 | asenovgrad
# Processing record 464 of Set 1 | erenhot
# Processing record 465 of Set 1 | vila velha
# Processing record 466 of Set 1 | axim
# Processing record 467 of Set 1 | rapid valley
# Processing record 468 of Set 1 | san quintin
# Processing record 469 of Set 1 | suozhen
# Processing record 470 of Set 1 | dianopolis
# dianopolis not found. Skipping...
# Processing record 471 of Set 1 | constitucion
# Processing record 472 of Set 1 | longkou
# Processing record 473 of Set 1 | hvammstangi
# hvammstangi not found. Skipping...
# Processing record 474 of Set 1 | ostersund
# Processing record 475 of Set 1 | seymchan
# Processing record 476 of Set 1 | bialogard
# Processing record 477 of Set 1 | qinhuangdao
# Processing record 478 of Set 1 | sitka
# Processing record 479 of Set 1 | mumford
# Processing record 480 of Set 1 | mazagao
# Processing record 481 of Set 1 | kruisfontein
# Processing record 482 of Set 1 | sao tome
# sao tome not found. Skipping...
# Processing record 483 of Set 1 | elat
# Processing record 484 of Set 1 | gat
# Processing record 485 of Set 1 | baoro
# Processing record 486 of Set 1 | waingapu
# Processing record 487 of Set 1 | pindiga
# Processing record 488 of Set 1 | zapolyarnyy
# Processing record 489 of Set 1 | maningrida
# Processing record 490 of Set 1 | kaa-khem
# Processing record 491 of Set 1 | ahipara
# Processing record 492 of Set 1 | roald
# Processing record 493 of Set 1 | boston
# Processing record 494 of Set 1 | fukue
# Processing record 495 of Set 1 | bastrop
# Processing record 496 of Set 1 | mingguang
# Processing record 497 of Set 1 | concarneau
# Processing record 498 of Set 1 | tortoli
# Processing record 499 of Set 1 | jalu
# Processing record 500 of Set 1 | asau
# asau not found. Skipping...
# Processing record 501 of Set 1 | okha
# Processing record 502 of Set 1 | kijang
# Processing record 503 of Set 1 | necochea
# Processing record 504 of Set 1 | cap malheureux
# Processing record 505 of Set 1 | ust-kut
# Processing record 506 of Set 1 | ayan
# Processing record 507 of Set 1 | karasburg
# Processing record 508 of Set 1 | yantal
# Processing record 509 of Set 1 | sungairaya
# Processing record 510 of Set 1 | muscat
# Processing record 511 of Set 1 | kazalinsk
# kazalinsk not found. Skipping...
# Processing record 512 of Set 1 | eyl
# Processing record 513 of Set 1 | castelldefels
# Processing record 514 of Set 1 | kristiinankaupunki
# kristiinankaupunki not found. Skipping...
# Processing record 515 of Set 1 | angol
# Processing record 516 of Set 1 | nouadhibou
# Processing record 517 of Set 1 | russell
# Processing record 518 of Set 1 | severodvinsk
# Processing record 519 of Set 1 | jiwani
# Processing record 520 of Set 1 | malyye derbety
# Processing record 521 of Set 1 | valley
# Processing record 522 of Set 1 | banda aceh
# Processing record 523 of Set 1 | korla
# korla not found. Skipping...
# Processing record 524 of Set 1 | riom
# Processing record 525 of Set 1 | morondava
# Processing record 526 of Set 1 | lasa
# Processing record 527 of Set 1 | sao filipe
# Processing record 528 of Set 1 | along
# Processing record 529 of Set 1 | muzhi
# Processing record 530 of Set 1 | bakchar
# Processing record 531 of Set 1 | jujuy
# jujuy not found. Skipping...
# Processing record 532 of Set 1 | jacareacanga
# Processing record 533 of Set 1 | svetlyy
# svetlyy not found. Skipping...
# Processing record 534 of Set 1 | primore
# primore not found. Skipping...
# Processing record 535 of Set 1 | namibe
# Processing record 536 of Set 1 | tuggurt
# tuggurt not found. Skipping...
# Processing record 537 of Set 1 | verkhnevilyuysk
# Processing record 538 of Set 1 | kamaishi
# Processing record 539 of Set 1 | kedrovyy
# Processing record 540 of Set 1 | turayf
# Processing record 541 of Set 1 | xuddur
# Processing record 542 of Set 1 | louisbourg
# louisbourg not found. Skipping...
# Processing record 543 of Set 1 | palana
# Processing record 544 of Set 1 | northam
# Processing record 545 of Set 1 | skibbereen
# Processing record 546 of Set 1 | galesong
# Processing record 547 of Set 1 | mareeba
# Processing record 548 of Set 1 | caramoran
# Processing record 549 of Set 1 | sibolga
# Processing record 550 of Set 1 | ponta do sol
# Processing record 551 of Set 1 | nacala
# Processing record 552 of Set 1 | madimba
# Processing record 553 of Set 1 | greenville
# Processing record 554 of Set 1 | tadine
# Processing record 555 of Set 1 | chake chake
# Processing record 556 of Set 1 | damghan
# Processing record 557 of Set 1 | zavallya
# Processing record 558 of Set 1 | troitskoye
# Processing record 559 of Set 1 | lima
# Processing record 560 of Set 1 | dzaoudzi
# Processing record 561 of Set 1 | caborca
# Processing record 562 of Set 1 | nioro
# Processing record 563 of Set 1 | sakaiminato
# Processing record 564 of Set 1 | road town
# Processing record 565 of Set 1 | lubben
# Processing record 566 of Set 1 | arman
# Processing record 567 of Set 1 | byron bay
# Processing record 568 of Set 1 | corpus christi
# Processing record 569 of Set 1 | dubna
# Processing record 570 of Set 1 | yangjiang
# Processing record 571 of Set 1 | verkhovazhye
# Processing record 572 of Set 1 | victoria point
# Processing record 573 of Set 1 | wajima
# Processing record 574 of Set 1 | north bend
# Processing record 575 of Set 1 | thinadhoo
# Processing record 576 of Set 1 | harper
# Processing record 577 of Set 1 | jinka
# Processing record 578 of Set 1 | marawi
# Processing record 579 of Set 1 | vengerovo
# Processing record 580 of Set 1 | verkhnyaya inta
# Processing record 581 of Set 1 | rumoi
# Processing record 582 of Set 1 | ghauspur
# Processing record 583 of Set 1 | daru
# Processing record 584 of Set 1 | sinnamary
# Processing record 585 of Set 1 | saint-leu
# Processing record 586 of Set 1 | sherlovaya gora
# Processing record 587 of Set 1 | cayenne
# Processing record 588 of Set 1 | pesaro
# Processing record 589 of Set 1 | general pico
# Processing record 590 of Set 1 | karauzyak
# karauzyak not found. Skipping...
# Processing record 591 of Set 1 | totness
# Processing record 592 of Set 1 | cilegon
# Processing record 593 of Set 1 | namatanai
# Processing record 594 of Set 1 | okato
# Processing record 595 of Set 1 | ovalle
# Processing record 596 of Set 1 | porbandar
# Processing record 597 of Set 1 | dawei
# Processing record 598 of Set 1 | lukovetskiy
# Processing record 599 of Set 1 | roma
# Processing record 600 of Set 1 | storforshei
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 66.4, 'lon': 14.52},
#  'dt': 1551418812,
#  'id': 3145614,
#  'main': {'humidity': 85,
#           'pressure': 1006,
#           'temp': 25.09,
#           'temp_max': 28.99,
#           'temp_min': 23},
#  'name': 'Storforshei',
#  'snow': {'1h': 0.25},
#  'sys': {'country': 'NO',
#          'id': 1651,
#          'message': 0.0043,
#          'sunrise': 1551420994,
#          'sunset': 1551456807,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light shower snow',
#               'icon': '13n',
#               'id': 620,
#               'main': 'Snow'}],
#  'wind': {'deg': 80, 'speed': 4.7}}

# %%
# Use list comprehension to gather necessary data series
lat_data = [data.get("coord").get("lat") for data in search_data]
lng_data = [data.get("coord").get("lon") for data in search_data]
temp_max = [data.get("main").get("temp_max") for data in search_data]
humid_data = [data.get("main").get("humidity") for data in search_data]
cloud_data =[data.get("clouds").get("all") for data in search_data]
wind_data = [data.get("wind").get("speed") for data in search_data]
date_data = [data.get("dt")for data in search_data]

# %%
# Create data frame with aggregated data
weather_data = pd.DataFrame({"City":cityList,
                             "Cloudiness":cloud_data,
                             "Country":countryList,
                             "Date":date_data,
                             "Humidity":humid_data,
                             "Lat":lat_data,
                             "Lng":lng_data,
                             "Max Temp":temp_max,
                             "Wind Speed":wind_data})

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = weather_data[["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]]
weather_data.count()
# Out:
# City          528
# Cloudiness    528
# Country       528
# Date          528
# Humidity      528
# Lat           528
# Lng           528
# Max Temp      528
# Wind Speed    528
# dtype: int64

# %%
weather_data.head(10)
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      ostrogozhsk          92      ru  1551418911        95  50.86   39.08
# 1            alofi          12      nu  1551416400        79 -19.06 -169.92
# 2  aleksandrov gay          80      ru  1551418911        95  50.14   48.57
# 3    leningradskiy          44      ru  1551418386        83  69.38  178.42
# 4       butaritari          92      ki  1551418371       100   3.07  172.79
# 5          qaanaaq           0      gl  1551418380        85  77.48  -69.36
# 6       georgetown           0      sh  1551416400        94   6.80  -58.16
# 7        carnarvon           0      au  1551418379        55 -30.97   22.13
# 8           dikson           0      ru  1551418399        74  73.51   80.55
# 9          talnakh          64      ru  1551418399        72  69.49   88.39
#
#    Max Temp  Wind Speed
# 0     33.52       12.01
# 1     84.20        9.17
# 2     29.38       15.48
# 3      9.13       12.24
# 4     81.98       19.51
# 5    -14.64        8.21
# 6     69.80        4.70
# 7     58.63        2.95
# 8     -0.19       16.26
# 9      5.48       19.28

# %%
# Save csv file
output_data_file=weather_data.to_csv("../output_data/cities.csv", index=False)

# %%
# Convert Unix Time Stamp to regular date
tmpDate = datetime.datetime.fromtimestamp(int(weather_data["Date"][0])).strftime('%Y-%m-%d')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Max Temp"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Max Temperature (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.ylim(30, 100)

plt.savefig("../output_data/MaxTmp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Humidity"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Humidity (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("../output_data/Humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Cloudiness"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Cloudiness (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.ylim(20, 100)

plt.savefig("../output_data/Cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Wind Speed"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Wind Speed (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.ylim(0, 30)

plt.savefig("../output_data/WindSpeed.png")

plt.show()
