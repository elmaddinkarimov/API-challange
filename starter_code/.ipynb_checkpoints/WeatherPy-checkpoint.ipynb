# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import random 
import numpy as np
import requests
import json 
import datetime
import time
from api_keys import api_key
from citipy import citipy
from pprint import pprint

output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 626

# %%
#Randomly generate latitude and longitude numbers. lookup nearest city using citipy

randCity = []
randCountry = []
loopcnt = 0

#Loop through until more than 500  city names are found

while len(randCity) < 700 :
    
    loopcnt +=1
    
    # Randomly generate latitude
    lat_pos = random.randint(0,2)
    base_lat = random.randint(0,91)
    dec_lat = random.random()/100
    lat = base_lat + dec_lat
    
    if lat_pos == 1:
        lat = lat * -1
    
    # Randomly generate longitude
    lng_pos = random.randint(0,2)
    base_lng = random.randint(0,181)
    dec_lng = random.random()/100
    lng = base_lng + dec_lng
    
    if lng_pos == 1:
        lng = lng * -1
         
    
    # Call citipy file to get nearest city based on random lat and lng
    city = citipy.nearest_city(lat, lng)
    
    # Test to see if the random city is already in the list, if not, add it to the city and country lists
    foundCity = False
    
    for j in range(len(randCity)):
        if city.city_name == randCity[j]:
            foundCity = True
            
    if foundCity==False  :   
        randCity.append(city.city_name)
        randCountry.append(city.country_code)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=b92b1e72d600408724344690fb8e3399&units=imperial&q=

# %%
# Loop through the list of cities and perform request for data on each
search_data = []
cityList = []
countryList = []

x = 0
print("Beginning Data Retrieval  ")
print("-------------------------------")

for city in randCity:
    x += 1
    print(f"Processing record {x} of Set 1 | {city}")   
    response = requests.get(query_url + city).json()
    searchCityID = response.get("id")
    
    if response.get("id"):      
        search_data.append(response)
        cityList.append(city)
        countryList.append(randCountry[x-1])
    else:
        print(f"{city} not found. Skipping...")
          
print("-------------------------------")
print("Data Retrieval Complete ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing record 1 of Set 1 | albany
# Processing record 2 of Set 1 | meulaboh
# Processing record 3 of Set 1 | severnyy
# severnyy not found. Skipping...
# Processing record 4 of Set 1 | tiksi
# Processing record 5 of Set 1 | hithadhoo
# Processing record 6 of Set 1 | barrow
# Processing record 7 of Set 1 | belushya guba
# belushya guba not found. Skipping...
# Processing record 8 of Set 1 | hamilton
# Processing record 9 of Set 1 | cidreira
# Processing record 10 of Set 1 | torbay
# Processing record 11 of Set 1 | mbanza-ngungu
# Processing record 12 of Set 1 | coffs harbour
# Processing record 13 of Set 1 | bubaque
# Processing record 14 of Set 1 | kapaa
# Processing record 15 of Set 1 | atuona
# Processing record 16 of Set 1 | oskemen
# Processing record 17 of Set 1 | rikitea
# Processing record 18 of Set 1 | shimoda
# Processing record 19 of Set 1 | iqaluit
# Processing record 20 of Set 1 | mataura
# Processing record 21 of Set 1 | port alfred
# Processing record 22 of Set 1 | bluff
# Processing record 23 of Set 1 | roma
# Processing record 24 of Set 1 | narva-joesuu
# Processing record 25 of Set 1 | santa cruz de la palma
# Processing record 26 of Set 1 | taolanaro
# taolanaro not found. Skipping...
# Processing record 27 of Set 1 | awbari
# Processing record 28 of Set 1 | grand gaube
# Processing record 29 of Set 1 | matara
# Processing record 30 of Set 1 | busselton
# Processing record 31 of Set 1 | codrington
# Processing record 32 of Set 1 | faanui
# Processing record 33 of Set 1 | manzhouli
# Processing record 34 of Set 1 | mys shmidta
# mys shmidta not found. Skipping...
# Processing record 35 of Set 1 | geraldton
# Processing record 36 of Set 1 | hilo
# Processing record 37 of Set 1 | saint-lo
# Processing record 38 of Set 1 | payson
# Processing record 39 of Set 1 | omsukchan
# Processing record 40 of Set 1 | tocache
# Processing record 41 of Set 1 | linguere
# linguere not found. Skipping...
# Processing record 42 of Set 1 | hasaki
# Processing record 43 of Set 1 | tondano
# Processing record 44 of Set 1 | port hardy
# Processing record 45 of Set 1 | jamestown
# Processing record 46 of Set 1 | show low
# Processing record 47 of Set 1 | rio grande
# Processing record 48 of Set 1 | mahebourg
# Processing record 49 of Set 1 | garrel
# Processing record 50 of Set 1 | ancud
# Processing record 51 of Set 1 | hobart
# Processing record 52 of Set 1 | ortigueira
# Processing record 53 of Set 1 | waipawa
# Processing record 54 of Set 1 | muros
# Processing record 55 of Set 1 | la baneza
# Processing record 56 of Set 1 | longyearbyen
# Processing record 57 of Set 1 | attawapiskat
# attawapiskat not found. Skipping...
# Processing record 58 of Set 1 | zhezkazgan
# Processing record 59 of Set 1 | corinto
# Processing record 60 of Set 1 | severo-kurilsk
# Processing record 61 of Set 1 | luanda
# Processing record 62 of Set 1 | jatiroto
# Processing record 63 of Set 1 | nikolskoye
# Processing record 64 of Set 1 | butaritari
# Processing record 65 of Set 1 | saskylakh
# Processing record 66 of Set 1 | saint-philippe
# Processing record 67 of Set 1 | lompoc
# Processing record 68 of Set 1 | vestmannaeyjar
# Processing record 69 of Set 1 | palasa
# palasa not found. Skipping...
# Processing record 70 of Set 1 | port blair
# Processing record 71 of Set 1 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing record 72 of Set 1 | bethel
# Processing record 73 of Set 1 | new norfolk
# Processing record 74 of Set 1 | ribeira grande
# Processing record 75 of Set 1 | alyangula
# Processing record 76 of Set 1 | avera
# Processing record 77 of Set 1 | pevek
# Processing record 78 of Set 1 | panuco
# Processing record 79 of Set 1 | batagay
# Processing record 80 of Set 1 | ilebo
# Processing record 81 of Set 1 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing record 82 of Set 1 | najran
# Processing record 83 of Set 1 | san jose
# Processing record 84 of Set 1 | ushuaia
# Processing record 85 of Set 1 | gravdal
# Processing record 86 of Set 1 | esperance
# Processing record 87 of Set 1 | ningan
# ningan not found. Skipping...
# Processing record 88 of Set 1 | kaitangata
# Processing record 89 of Set 1 | flinders
# Processing record 90 of Set 1 | cape town
# Processing record 91 of Set 1 | verkhnyaya inta
# Processing record 92 of Set 1 | lac du bonnet
# Processing record 93 of Set 1 | itarema
# Processing record 94 of Set 1 | kingman
# Processing record 95 of Set 1 | lindi
# Processing record 96 of Set 1 | carnarvon
# Processing record 97 of Set 1 | yellowknife
# Processing record 98 of Set 1 | ninh binh
# Processing record 99 of Set 1 | kaeo
# Processing record 100 of Set 1 | victoria
# Processing record 101 of Set 1 | castro
# Processing record 102 of Set 1 | tarudant
# tarudant not found. Skipping...
# Processing record 103 of Set 1 | qaanaaq
# Processing record 104 of Set 1 | karaul
# karaul not found. Skipping...
# Processing record 105 of Set 1 | allapalli
# Processing record 106 of Set 1 | hermanus
# Processing record 107 of Set 1 | bilibino
# Processing record 108 of Set 1 | sidrolandia
# Processing record 109 of Set 1 | durusu
# Processing record 110 of Set 1 | kiunga
# Processing record 111 of Set 1 | coahuayana
# Processing record 112 of Set 1 | sidi ali
# Processing record 113 of Set 1 | lukovetskiy
# Processing record 114 of Set 1 | laguna
# Processing record 115 of Set 1 | katsuura
# Processing record 116 of Set 1 | tura
# Processing record 117 of Set 1 | tasiilaq
# Processing record 118 of Set 1 | klaksvik
# Processing record 119 of Set 1 | komsomolskiy
# Processing record 120 of Set 1 | barentsburg
# barentsburg not found. Skipping...
# Processing record 121 of Set 1 | khatanga
# Processing record 122 of Set 1 | vaini
# Processing record 123 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing record 124 of Set 1 | starachowice
# Processing record 125 of Set 1 | aitape
# Processing record 126 of Set 1 | salalah
# Processing record 127 of Set 1 | ulaangom
# Processing record 128 of Set 1 | thompson
# Processing record 129 of Set 1 | palmer
# Processing record 130 of Set 1 | cheuskiny
# cheuskiny not found. Skipping...
# Processing record 131 of Set 1 | lhuntshi
# lhuntshi not found. Skipping...
# Processing record 132 of Set 1 | torva
# Processing record 133 of Set 1 | zeya
# Processing record 134 of Set 1 | tawang
# Processing record 135 of Set 1 | norman wells
# Processing record 136 of Set 1 | eldikan
# eldikan not found. Skipping...
# Processing record 137 of Set 1 | te anau
# Processing record 138 of Set 1 | beloha
# Processing record 139 of Set 1 | danilov
# Processing record 140 of Set 1 | acuna
# acuna not found. Skipping...
# Processing record 141 of Set 1 | leshukonskoye
# Processing record 142 of Set 1 | hami
# Processing record 143 of Set 1 | arlit
# Processing record 144 of Set 1 | sur
# Processing record 145 of Set 1 | yirol
# yirol not found. Skipping...
# Processing record 146 of Set 1 | petrozavodsk
# Processing record 147 of Set 1 | kidal
# Processing record 148 of Set 1 | hervey bay
# Processing record 149 of Set 1 | amderma
# amderma not found. Skipping...
# Processing record 150 of Set 1 | hagersville
# Processing record 151 of Set 1 | constitucion
# Processing record 152 of Set 1 | iracoubo
# Processing record 153 of Set 1 | awjilah
# Processing record 154 of Set 1 | upernavik
# Processing record 155 of Set 1 | bambous virieux
# Processing record 156 of Set 1 | chaochou
# chaochou not found. Skipping...
# Processing record 157 of Set 1 | nanortalik
# Processing record 158 of Set 1 | ixtapa
# Processing record 159 of Set 1 | bredasdorp
# Processing record 160 of Set 1 | baykit
# Processing record 161 of Set 1 | saint-georges
# Processing record 162 of Set 1 | spanish town
# Processing record 163 of Set 1 | kismayo
# kismayo not found. Skipping...
# Processing record 164 of Set 1 | flin flon
# Processing record 165 of Set 1 | clyde river
# Processing record 166 of Set 1 | pangnirtung
# Processing record 167 of Set 1 | barbar
# barbar not found. Skipping...
# Processing record 168 of Set 1 | ponta do sol
# Processing record 169 of Set 1 | rovaniemi
# Processing record 170 of Set 1 | nouadhibou
# Processing record 171 of Set 1 | cabo san lucas
# Processing record 172 of Set 1 | sukhobezvodnoye
# Processing record 173 of Set 1 | dzhebariki-khaya
# Processing record 174 of Set 1 | lorengau
# Processing record 175 of Set 1 | guajara
# Processing record 176 of Set 1 | jaromerice nad rokytnou
# Processing record 177 of Set 1 | kavieng
# Processing record 178 of Set 1 | jertih
# Processing record 179 of Set 1 | anzio
# Processing record 180 of Set 1 | kavaratti
# Processing record 181 of Set 1 | namatanai
# Processing record 182 of Set 1 | bairiki
# bairiki not found. Skipping...
# Processing record 183 of Set 1 | mizdah
# Processing record 184 of Set 1 | pareora
# Processing record 185 of Set 1 | jizan
# Processing record 186 of Set 1 | kalga
# Processing record 187 of Set 1 | rognan
# Processing record 188 of Set 1 | zalantun
# Processing record 189 of Set 1 | pula
# Processing record 190 of Set 1 | xining
# Processing record 191 of Set 1 | narsaq
# Processing record 192 of Set 1 | dikson
# Processing record 193 of Set 1 | sitka
# Processing record 194 of Set 1 | talnakh
# Processing record 195 of Set 1 | cherskiy
# Processing record 196 of Set 1 | faya
# Processing record 197 of Set 1 | lasa
# Processing record 198 of Set 1 | orangeburg
# Processing record 199 of Set 1 | kulhudhuffushi
# Processing record 200 of Set 1 | qaracala
# Processing record 201 of Set 1 | punta arenas
# Processing record 202 of Set 1 | port-gentil
# Processing record 203 of Set 1 | east london
# Processing record 204 of Set 1 | khani
# Processing record 205 of Set 1 | korla
# korla not found. Skipping...
# Processing record 206 of Set 1 | fortuna
# Processing record 207 of Set 1 | sisophon
# Processing record 208 of Set 1 | mount gambier
# Processing record 209 of Set 1 | adre
# Processing record 210 of Set 1 | jalu
# Processing record 211 of Set 1 | nerchinskiy zavod
# Processing record 212 of Set 1 | chuy
# Processing record 213 of Set 1 | simao
# Processing record 214 of Set 1 | lerwick
# Processing record 215 of Set 1 | louisbourg
# louisbourg not found. Skipping...
# Processing record 216 of Set 1 | vardo
# Processing record 217 of Set 1 | vygonichi
# Processing record 218 of Set 1 | cockburn town
# Processing record 219 of Set 1 | darnah
# Processing record 220 of Set 1 | veraval
# Processing record 221 of Set 1 | chapais
# Processing record 222 of Set 1 | west lake stevens
# Processing record 223 of Set 1 | iquique
# Processing record 224 of Set 1 | hambantota
# Processing record 225 of Set 1 | virginia beach
# Processing record 226 of Set 1 | la celia
# Processing record 227 of Set 1 | cherepanovo
# Processing record 228 of Set 1 | hofn
# Processing record 229 of Set 1 | touros
# Processing record 230 of Set 1 | kazalinsk
# kazalinsk not found. Skipping...
# Processing record 231 of Set 1 | aloleng
# Processing record 232 of Set 1 | alofi
# Processing record 233 of Set 1 | kieta
# Processing record 234 of Set 1 | umzimvubu
# umzimvubu not found. Skipping...
# Processing record 235 of Set 1 | bertoua
# Processing record 236 of Set 1 | komarikhinskiy
# Processing record 237 of Set 1 | grand river south east
# grand river south east not found. Skipping...
# Processing record 238 of Set 1 | christchurch
# Processing record 239 of Set 1 | tidore
# tidore not found. Skipping...
# Processing record 240 of Set 1 | teknaf
# Processing record 241 of Set 1 | mayo
# Processing record 242 of Set 1 | mecca
# Processing record 243 of Set 1 | banda aceh
# Processing record 244 of Set 1 | puerto ayora
# Processing record 245 of Set 1 | chokurdakh
# Processing record 246 of Set 1 | tuktoyaktuk
# Processing record 247 of Set 1 | riorges
# Processing record 248 of Set 1 | nisia floresta
# Processing record 249 of Set 1 | rawson
# Processing record 250 of Set 1 | okhotsk
# Processing record 251 of Set 1 | ullapool
# Processing record 252 of Set 1 | waddan
# Processing record 253 of Set 1 | kodiak
# Processing record 254 of Set 1 | arraial do cabo
# Processing record 255 of Set 1 | uthal
# Processing record 256 of Set 1 | aklavik
# Processing record 257 of Set 1 | teguldet
# Processing record 258 of Set 1 | itaituba
# Processing record 259 of Set 1 | ilulissat
# Processing record 260 of Set 1 | mentok
# mentok not found. Skipping...
# Processing record 261 of Set 1 | salamanca
# Processing record 262 of Set 1 | ust-kulom
# Processing record 263 of Set 1 | georgetown
# Processing record 264 of Set 1 | menongue
# Processing record 265 of Set 1 | comodoro rivadavia
# Processing record 266 of Set 1 | provideniya
# Processing record 267 of Set 1 | balykshi
# balykshi not found. Skipping...
# Processing record 268 of Set 1 | evensk
# Processing record 269 of Set 1 | alta floresta
# Processing record 270 of Set 1 | morondava
# Processing record 271 of Set 1 | bakchar
# Processing record 272 of Set 1 | newport
# Processing record 273 of Set 1 | colares
# Processing record 274 of Set 1 | tsihombe
# tsihombe not found. Skipping...
# Processing record 275 of Set 1 | umm lajj
# Processing record 276 of Set 1 | hirara
# Processing record 277 of Set 1 | alanya
# Processing record 278 of Set 1 | yumen
# Processing record 279 of Set 1 | grindavik
# Processing record 280 of Set 1 | ratnagiri
# Processing record 281 of Set 1 | libenge
# Processing record 282 of Set 1 | acapulco
# Processing record 283 of Set 1 | hovd
# Processing record 284 of Set 1 | bekhtery
# Processing record 285 of Set 1 | ust-karsk
# Processing record 286 of Set 1 | vanimo
# Processing record 287 of Set 1 | verkhoyansk
# Processing record 288 of Set 1 | novokuznetsk
# Processing record 289 of Set 1 | ostrovnoy
# Processing record 290 of Set 1 | tuatapere
# Processing record 291 of Set 1 | kyle
# Processing record 292 of Set 1 | shieli
# Processing record 293 of Set 1 | ahipara
# Processing record 294 of Set 1 | achisay
# achisay not found. Skipping...
# Processing record 295 of Set 1 | umea
# Processing record 296 of Set 1 | thinadhoo
# Processing record 297 of Set 1 | lebu
# Processing record 298 of Set 1 | vao
# Processing record 299 of Set 1 | hurghada
# hurghada not found. Skipping...
# Processing record 300 of Set 1 | maragogi
# Processing record 301 of Set 1 | kununurra
# Processing record 302 of Set 1 | akyab
# akyab not found. Skipping...
# Processing record 303 of Set 1 | yeletskiy
# yeletskiy not found. Skipping...
# Processing record 304 of Set 1 | san andres
# Processing record 305 of Set 1 | atambua
# Processing record 306 of Set 1 | muroto
# Processing record 307 of Set 1 | bathsheba
# Processing record 308 of Set 1 | manggar
# Processing record 309 of Set 1 | dhola
# Processing record 310 of Set 1 | yulara
# Processing record 311 of Set 1 | mansa
# Processing record 312 of Set 1 | badvel
# Processing record 313 of Set 1 | bulawayo
# Processing record 314 of Set 1 | varkaus
# Processing record 315 of Set 1 | broken hill
# Processing record 316 of Set 1 | turgoyak
# Processing record 317 of Set 1 | caconda
# Processing record 318 of Set 1 | svetlogorsk
# Processing record 319 of Set 1 | sao felix do xingu
# Processing record 320 of Set 1 | kjollefjord
# Processing record 321 of Set 1 | san ramon
# Processing record 322 of Set 1 | boralday
# Processing record 323 of Set 1 | ahrarne
# ahrarne not found. Skipping...
# Processing record 324 of Set 1 | mangrol
# Processing record 325 of Set 1 | lavrentiya
# Processing record 326 of Set 1 | kuche
# kuche not found. Skipping...
# Processing record 327 of Set 1 | tuzla
# tuzla not found. Skipping...
# Processing record 328 of Set 1 | khandyga
# Processing record 329 of Set 1 | caraquet
# Processing record 330 of Set 1 | kruisfontein
# Processing record 331 of Set 1 | tilichiki
# Processing record 332 of Set 1 | guerrero negro
# Processing record 333 of Set 1 | blagoevgrad
# Processing record 334 of Set 1 | churapcha
# Processing record 335 of Set 1 | atka
# atka not found. Skipping...
# Processing record 336 of Set 1 | beringovskiy
# Processing record 337 of Set 1 | samusu
# samusu not found. Skipping...
# Processing record 338 of Set 1 | phan rang
# phan rang not found. Skipping...
# Processing record 339 of Set 1 | kudahuvadhoo
# Processing record 340 of Set 1 | geresk
# geresk not found. Skipping...
# Processing record 341 of Set 1 | los banos
# Processing record 342 of Set 1 | kuvandyk
# Processing record 343 of Set 1 | margate
# Processing record 344 of Set 1 | richards bay
# Processing record 345 of Set 1 | haverhill
# Processing record 346 of Set 1 | mar del plata
# Processing record 347 of Set 1 | singaraja
# Processing record 348 of Set 1 | saint-augustin
# Processing record 349 of Set 1 | juquitiba
# Processing record 350 of Set 1 | malakal
# malakal not found. Skipping...
# Processing record 351 of Set 1 | odweyne
# odweyne not found. Skipping...
# Processing record 352 of Set 1 | sao filipe
# Processing record 353 of Set 1 | tokur
# Processing record 354 of Set 1 | san policarpo
# Processing record 355 of Set 1 | umm kaddadah
# Processing record 356 of Set 1 | bilma
# Processing record 357 of Set 1 | barkot
# Processing record 358 of Set 1 | damghan
# Processing record 359 of Set 1 | kazanka
# Processing record 360 of Set 1 | kholtoson
# Processing record 361 of Set 1 | bandar-e lengeh
# Processing record 362 of Set 1 | milingimbi
# milingimbi not found. Skipping...
# Processing record 363 of Set 1 | erenhot
# Processing record 364 of Set 1 | acajutla
# Processing record 365 of Set 1 | dzheguta
# Processing record 366 of Set 1 | monrovia
# Processing record 367 of Set 1 | fernandez
# Processing record 368 of Set 1 | lingao
# Processing record 369 of Set 1 | mwene-ditu
# Processing record 370 of Set 1 | soyo
# Processing record 371 of Set 1 | hobyo
# Processing record 372 of Set 1 | kultuk
# Processing record 373 of Set 1 | souillac
# Processing record 374 of Set 1 | baoying
# Processing record 375 of Set 1 | kamenskoye
# kamenskoye not found. Skipping...
# Processing record 376 of Set 1 | naze
# Processing record 377 of Set 1 | qarqin
# Processing record 378 of Set 1 | damavand
# Processing record 379 of Set 1 | le port
# Processing record 380 of Set 1 | kijang
# Processing record 381 of Set 1 | zolotinka
# zolotinka not found. Skipping...
# Processing record 382 of Set 1 | port lincoln
# Processing record 383 of Set 1 | ofaqim
# Processing record 384 of Set 1 | puksoozero
# Processing record 385 of Set 1 | sisimiut
# Processing record 386 of Set 1 | airai
# Processing record 387 of Set 1 | aztec
# Processing record 388 of Set 1 | solnechnyy
# Processing record 389 of Set 1 | tula
# Processing record 390 of Set 1 | astana
# Processing record 391 of Set 1 | port elizabeth
# Processing record 392 of Set 1 | chitral
# Processing record 393 of Set 1 | antofagasta
# Processing record 394 of Set 1 | leningradskiy
# Processing record 395 of Set 1 | tubruq
# tubruq not found. Skipping...
# Processing record 396 of Set 1 | saint-joseph
# Processing record 397 of Set 1 | mehamn
# Processing record 398 of Set 1 | ugoofaaru
# Processing record 399 of Set 1 | taoudenni
# Processing record 400 of Set 1 | menzelinsk
# Processing record 401 of Set 1 | tarko-sale
# Processing record 402 of Set 1 | westport
# Processing record 403 of Set 1 | moron
# Processing record 404 of Set 1 | kiruna
# Processing record 405 of Set 1 | glencoe
# Processing record 406 of Set 1 | zalaszentgrot
# Processing record 407 of Set 1 | chodziez
# Processing record 408 of Set 1 | myitkyina
# Processing record 409 of Set 1 | broome
# Processing record 410 of Set 1 | codajas
# Processing record 411 of Set 1 | havelock
# Processing record 412 of Set 1 | along
# Processing record 413 of Set 1 | rensvik
# Processing record 414 of Set 1 | jian
# Processing record 415 of Set 1 | vostok
# Processing record 416 of Set 1 | lagoa
# Processing record 417 of Set 1 | biloela
# Processing record 418 of Set 1 | aflu
# aflu not found. Skipping...
# Processing record 419 of Set 1 | rayevskiy
# Processing record 420 of Set 1 | sorland
# Processing record 421 of Set 1 | fuzhou
# Processing record 422 of Set 1 | agva
# agva not found. Skipping...
# Processing record 423 of Set 1 | waterloo
# Processing record 424 of Set 1 | buluang
# Processing record 425 of Set 1 | misratah
# Processing record 426 of Set 1 | chernyshevskiy
# Processing record 427 of Set 1 | saldanha
# Processing record 428 of Set 1 | riyadh
# Processing record 429 of Set 1 | phun phin
# phun phin not found. Skipping...
# Processing record 430 of Set 1 | inta
# Processing record 431 of Set 1 | dingle
# Processing record 432 of Set 1 | shakiso
# Processing record 433 of Set 1 | ziro
# Processing record 434 of Set 1 | santiago del estero
# Processing record 435 of Set 1 | bonavista
# Processing record 436 of Set 1 | zahnitkiv
# Processing record 437 of Set 1 | san vicente
# Processing record 438 of Set 1 | zheleznodorozhnyy
# Processing record 439 of Set 1 | whitehorse
# Processing record 440 of Set 1 | harper
# Processing record 441 of Set 1 | porbandar
# Processing record 442 of Set 1 | kungalv
# Processing record 443 of Set 1 | baruun-urt
# Processing record 444 of Set 1 | manokwari
# Processing record 445 of Set 1 | monterey
# Processing record 446 of Set 1 | male
# Processing record 447 of Set 1 | berlevag
# Processing record 448 of Set 1 | rio claro
# Processing record 449 of Set 1 | kendari
# Processing record 450 of Set 1 | balkhash
# Processing record 451 of Set 1 | marcona
# marcona not found. Skipping...
# Processing record 452 of Set 1 | clervaux
# Processing record 453 of Set 1 | rawannawi
# rawannawi not found. Skipping...
# Processing record 454 of Set 1 | polessk
# Processing record 455 of Set 1 | lang suan
# Processing record 456 of Set 1 | makinsk
# Processing record 457 of Set 1 | labuan
# Processing record 458 of Set 1 | shar
# Processing record 459 of Set 1 | hokitika
# Processing record 460 of Set 1 | kushima
# Processing record 461 of Set 1 | sola
# Processing record 462 of Set 1 | sindand
# sindand not found. Skipping...
# Processing record 463 of Set 1 | orlovskiy
# Processing record 464 of Set 1 | hay river
# Processing record 465 of Set 1 | narasannapeta
# Processing record 466 of Set 1 | bud
# Processing record 467 of Set 1 | dothan
# Processing record 468 of Set 1 | isangel
# Processing record 469 of Set 1 | diapaga
# Processing record 470 of Set 1 | mogadishu
# Processing record 471 of Set 1 | bratsk
# Processing record 472 of Set 1 | nyurba
# Processing record 473 of Set 1 | baijiantan
# Processing record 474 of Set 1 | zhigansk
# Processing record 475 of Set 1 | kupang
# Processing record 476 of Set 1 | octeville
# Processing record 477 of Set 1 | rapar
# Processing record 478 of Set 1 | impfondo
# Processing record 479 of Set 1 | padang
# Processing record 480 of Set 1 | strezhevoy
# Processing record 481 of Set 1 | hongjiang
# Processing record 482 of Set 1 | fryazino
# Processing record 483 of Set 1 | kadykchan
# kadykchan not found. Skipping...
# Processing record 484 of Set 1 | olinda
# Processing record 485 of Set 1 | spirit river
# Processing record 486 of Set 1 | bani walid
# Processing record 487 of Set 1 | zhucheng
# Processing record 488 of Set 1 | san quintin
# Processing record 489 of Set 1 | ngorongoro
# Processing record 490 of Set 1 | mikkeli
# Processing record 491 of Set 1 | mustasaari
# Processing record 492 of Set 1 | pitimbu
# Processing record 493 of Set 1 | yar-sale
# Processing record 494 of Set 1 | gannan
# Processing record 495 of Set 1 | espinosa
# Processing record 496 of Set 1 | viligili
# viligili not found. Skipping...
# Processing record 497 of Set 1 | fairbanks
# Processing record 498 of Set 1 | vanderhoof
# Processing record 499 of Set 1 | sept-iles
# Processing record 500 of Set 1 | agadez
# Processing record 501 of Set 1 | sambava
# Processing record 502 of Set 1 | onega
# Processing record 503 of Set 1 | kholmy
# Processing record 504 of Set 1 | carutapera
# Processing record 505 of Set 1 | nakamura
# Processing record 506 of Set 1 | drochia
# Processing record 507 of Set 1 | shakawe
# Processing record 508 of Set 1 | dzaoudzi
# Processing record 509 of Set 1 | deputatskiy
# Processing record 510 of Set 1 | kirakira
# Processing record 511 of Set 1 | babanusah
# babanusah not found. Skipping...
# Processing record 512 of Set 1 | avarua
# Processing record 513 of Set 1 | payo
# Processing record 514 of Set 1 | severobaykalsk
# Processing record 515 of Set 1 | lebedinyy
# Processing record 516 of Set 1 | vozdvizhenka
# Processing record 517 of Set 1 | rongai
# Processing record 518 of Set 1 | northam
# Processing record 519 of Set 1 | dayong
# Processing record 520 of Set 1 | kuytun
# Processing record 521 of Set 1 | ust-bolsheretsk
# ust-bolsheretsk not found. Skipping...
# Processing record 522 of Set 1 | bolshegrivskoye
# bolshegrivskoye not found. Skipping...
# Processing record 523 of Set 1 | road town
# Processing record 524 of Set 1 | teacapan
# Processing record 525 of Set 1 | neiafu
# Processing record 526 of Set 1 | chagda
# chagda not found. Skipping...
# Processing record 527 of Set 1 | port augusta
# Processing record 528 of Set 1 | loding
# Processing record 529 of Set 1 | aleppo
# Processing record 530 of Set 1 | muisne
# Processing record 531 of Set 1 | gardan diwal
# gardan diwal not found. Skipping...
# Processing record 532 of Set 1 | yerbogachen
# Processing record 533 of Set 1 | zhmerynka
# Processing record 534 of Set 1 | tessalit
# Processing record 535 of Set 1 | dong hoi
# Processing record 536 of Set 1 | karkaralinsk
# karkaralinsk not found. Skipping...
# Processing record 537 of Set 1 | grenville
# Processing record 538 of Set 1 | urdzhar
# urdzhar not found. Skipping...
# Processing record 539 of Set 1 | mao
# Processing record 540 of Set 1 | dzilam gonzalez
# Processing record 541 of Set 1 | santa cruz
# Processing record 542 of Set 1 | imbituba
# Processing record 543 of Set 1 | funtua
# Processing record 544 of Set 1 | amla
# Processing record 545 of Set 1 | makakilo city
# Processing record 546 of Set 1 | aswan
# Processing record 547 of Set 1 | kahului
# Processing record 548 of Set 1 | mbuji-mayi
# Processing record 549 of Set 1 | rantepao
# Processing record 550 of Set 1 | assiniboia
# Processing record 551 of Set 1 | osinovo
# Processing record 552 of Set 1 | noumea
# Processing record 553 of Set 1 | zonguldak
# Processing record 554 of Set 1 | inuvik
# Processing record 555 of Set 1 | sobolevo
# Processing record 556 of Set 1 | luderitz
# Processing record 557 of Set 1 | tumannyy
# tumannyy not found. Skipping...
# Processing record 558 of Set 1 | dubti
# Processing record 559 of Set 1 | krapina
# Processing record 560 of Set 1 | byron bay
# Processing record 561 of Set 1 | san patricio
# Processing record 562 of Set 1 | campo verde
# Processing record 563 of Set 1 | ntungamo
# Processing record 564 of Set 1 | inyonga
# Processing record 565 of Set 1 | saint-francois
# Processing record 566 of Set 1 | mosquera
# Processing record 567 of Set 1 | genhe
# Processing record 568 of Set 1 | sernur
# Processing record 569 of Set 1 | zig
# Processing record 570 of Set 1 | bolshaya vishera
# bolshaya vishera not found. Skipping...
# Processing record 571 of Set 1 | vohibinany
# Processing record 572 of Set 1 | los llanos de aridane
# Processing record 573 of Set 1 | kloulklubed
# Processing record 574 of Set 1 | skalistyy
# skalistyy not found. Skipping...
# Processing record 575 of Set 1 | anloga
# Processing record 576 of Set 1 | constantine
# Processing record 577 of Set 1 | nemyriv
# Processing record 578 of Set 1 | santa eulalia del rio
# santa eulalia del rio not found. Skipping...
# Processing record 579 of Set 1 | vodnyy
# Processing record 580 of Set 1 | general pico
# Processing record 581 of Set 1 | nishihara
# Processing record 582 of Set 1 | sohag
# Processing record 583 of Set 1 | maldonado
# Processing record 584 of Set 1 | arshan
# Processing record 585 of Set 1 | merauke
# Processing record 586 of Set 1 | bambanglipuro
# Processing record 587 of Set 1 | dwarka
# Processing record 588 of Set 1 | chaumont
# Processing record 589 of Set 1 | nipawin
# Processing record 590 of Set 1 | pa sang
# Processing record 591 of Set 1 | bahia honda
# Processing record 592 of Set 1 | pafos
# pafos not found. Skipping...
# Processing record 593 of Set 1 | abha
# Processing record 594 of Set 1 | nouna
# Processing record 595 of Set 1 | son la
# Processing record 596 of Set 1 | mayumba
# Processing record 597 of Set 1 | kapoeta
# kapoeta not found. Skipping...
# Processing record 598 of Set 1 | ovalle
# Processing record 599 of Set 1 | gurgan
# gurgan not found. Skipping...
# Processing record 600 of Set 1 | burgeo
# Processing record 601 of Set 1 | yarim
# Processing record 602 of Set 1 | teahupoo
# Processing record 603 of Set 1 | batemans bay
# Processing record 604 of Set 1 | kewanee
# Processing record 605 of Set 1 | kondinskoye
# Processing record 606 of Set 1 | buchanan
# Processing record 607 of Set 1 | araouane
# Processing record 608 of Set 1 | mangan
# Processing record 609 of Set 1 | ksenyevka
# ksenyevka not found. Skipping...
# Processing record 610 of Set 1 | bjelovar
# Processing record 611 of Set 1 | elliot
# Processing record 612 of Set 1 | palana
# Processing record 613 of Set 1 | marzuq
# Processing record 614 of Set 1 | necochea
# Processing record 615 of Set 1 | galle
# Processing record 616 of Set 1 | manali
# Processing record 617 of Set 1 | chumikan
# Processing record 618 of Set 1 | choma
# Processing record 619 of Set 1 | dandong
# Processing record 620 of Set 1 | agidel
# Processing record 621 of Set 1 | sholavandan
# sholavandan not found. Skipping...
# Processing record 622 of Set 1 | fukue
# Processing record 623 of Set 1 | bentiu
# bentiu not found. Skipping...
# Processing record 624 of Set 1 | brewster
# Processing record 625 of Set 1 | bac lieu
# bac lieu not found. Skipping...
# Processing record 626 of Set 1 | butler
# Processing record 627 of Set 1 | banjar
# Processing record 628 of Set 1 | afmadu
# afmadu not found. Skipping...
# Processing record 629 of Set 1 | hohhot
# Processing record 630 of Set 1 | xiamen
# Processing record 631 of Set 1 | janfida
# Processing record 632 of Set 1 | owando
# Processing record 633 of Set 1 | krasnoarmeysk
# Processing record 634 of Set 1 | tongliao
# Processing record 635 of Set 1 | abaza
# Processing record 636 of Set 1 | xghajra
# xghajra not found. Skipping...
# Processing record 637 of Set 1 | taksimo
# Processing record 638 of Set 1 | sydney
# Processing record 639 of Set 1 | rungata
# rungata not found. Skipping...
# Processing record 640 of Set 1 | kitimat
# Processing record 641 of Set 1 | tabiauea
# tabiauea not found. Skipping...
# Processing record 642 of Set 1 | bacolod
# Processing record 643 of Set 1 | svetlyy
# svetlyy not found. Skipping...
# Processing record 644 of Set 1 | vila velha
# Processing record 645 of Set 1 | aksarka
# Processing record 646 of Set 1 | saleaula
# saleaula not found. Skipping...
# Processing record 647 of Set 1 | namanyere
# Processing record 648 of Set 1 | srednekolymsk
# Processing record 649 of Set 1 | medvedka
# Processing record 650 of Set 1 | ponta delgada
# Processing record 651 of Set 1 | yatou
# Processing record 652 of Set 1 | lincoln
# Processing record 653 of Set 1 | kushiro
# Processing record 654 of Set 1 | dasoguz
# Processing record 655 of Set 1 | namibe
# Processing record 656 of Set 1 | mandera
# Processing record 657 of Set 1 | bacuit
# bacuit not found. Skipping...
# Processing record 658 of Set 1 | maceio
# Processing record 659 of Set 1 | sidi bu zayd
# sidi bu zayd not found. Skipping...
# Processing record 660 of Set 1 | salvacion
# Processing record 661 of Set 1 | nuuk
# Processing record 662 of Set 1 | chokwe
# chokwe not found. Skipping...
# Processing record 663 of Set 1 | zhuhai
# Processing record 664 of Set 1 | marica
# Processing record 665 of Set 1 | makhachkala
# Processing record 666 of Set 1 | ampanihy
# Processing record 667 of Set 1 | sulangan
# Processing record 668 of Set 1 | san cristobal
# Processing record 669 of Set 1 | sergeyevka
# Processing record 670 of Set 1 | methoni
# Processing record 671 of Set 1 | teneguiban
# teneguiban not found. Skipping...
# Processing record 672 of Set 1 | etla
# Processing record 673 of Set 1 | gibara
# Processing record 674 of Set 1 | vung tau
# Processing record 675 of Set 1 | hun
# Processing record 676 of Set 1 | svobody
# Processing record 677 of Set 1 | lakselv
# Processing record 678 of Set 1 | malanville
# Processing record 679 of Set 1 | sijunjung
# Processing record 680 of Set 1 | jacksonville
# Processing record 681 of Set 1 | puerto carreno
# Processing record 682 of Set 1 | arkhara
# Processing record 683 of Set 1 | tamale
# Processing record 684 of Set 1 | rovenki
# Processing record 685 of Set 1 | bundaberg
# Processing record 686 of Set 1 | wukari
# Processing record 687 of Set 1 | celestun
# Processing record 688 of Set 1 | lewistown
# Processing record 689 of Set 1 | salgar
# Processing record 690 of Set 1 | indija
# Processing record 691 of Set 1 | sharjah
# Processing record 692 of Set 1 | sinnamary
# Processing record 693 of Set 1 | lokosovo
# Processing record 694 of Set 1 | pokosnoye
# Processing record 695 of Set 1 | ozernovskiy
# Processing record 696 of Set 1 | brae
# Processing record 697 of Set 1 | tigil
# Processing record 698 of Set 1 | bandarbeyla
# Processing record 699 of Set 1 | marsabit
# Processing record 700 of Set 1 | egvekinot
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 66.32, 'lon': -179.17},
#  'dt': 1551418504,
#  'id': 4031742,
#  'main': {'grnd_level': 939.89,
#           'humidity': 84,
#           'pressure': 992.21,
#           'sea_level': 992.21,
#           'temp': 27.94,
#           'temp_max': 27.94,
#           'temp_min': 27.94},
#  'name': 'Egvekinot',
#  'sys': {'country': 'RU',
#          'message': 0.004,
#          'sunrise': 1551467342,
#          'sunset': 1551503418},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102.5, 'speed': 13.8}}

# %%
# Use list comprehension to gather necessary data series
lat_data = [data.get("coord").get("lat") for data in search_data]
lng_data = [data.get("coord").get("lon") for data in search_data]
temp_max = [data.get("main").get("temp_max") for data in search_data]
humid_data = [data.get("main").get("humidity") for data in search_data]
cloud_data =[data.get("clouds").get("all") for data in search_data]
wind_data = [data.get("wind").get("speed") for data in search_data]
date_data = [data.get("dt")for data in search_data]

# %%
# Create data frame with aggregated data
weather_data = pd.DataFrame({"City":cityList,
                             "Cloudiness":cloud_data,
                             "Country":countryList,
                             "Date":date_data,
                             "Humidity":humid_data,
                             "Lat":lat_data,
                             "Lng":lng_data,
                             "Max Temp":temp_max,
                             "Wind Speed":wind_data})

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = weather_data[["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]]
weather_data.count()
# Out:
# City          614
# Cloudiness    614
# Country       614
# Date          614
# Humidity      614
# Lat           614
# Lng           614
# Max Temp      614
# Wind Speed    614
# dtype: int64

# %%
weather_data.head(10)
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         albany          90      au  1551417782        72  42.65  -73.75
# 1       meulaboh          64      id  1551418359       100   4.14   96.13
# 2          tiksi          64      ru  1551418359        58  71.64  128.87
# 3      hithadhoo           8      mv  1551418359       100  -0.60   73.08
# 4         barrow          36      us  1551417949        64 -38.31  -60.23
# 5       hamilton          40      bm  1551418220        88  32.30  -64.78
# 6       cidreira           0      br  1551418360        97 -30.17  -50.22
# 7         torbay          75      ca  1551418356        67  47.66  -52.73
# 8  mbanza-ngungu          92      cd  1551418088        95  -5.25   14.87
# 9  coffs harbour          92      au  1551418101        61 -30.30  153.13
#
#    Max Temp  Wind Speed
# 0     18.00        2.28
# 1     81.04        4.63
# 2      1.88       12.12
# 3     82.79       12.35
# 4     59.44       13.47
# 5     66.20       17.22
# 6     63.31        5.86
# 7     19.00       26.40
# 8     72.08        4.29
# 9     82.00       11.41

# %%
# Save csv file
output_data_file=weather_data.to_csv("../output_data/cities.csv", index=False)

# %%
# Convert Unix Time Stamp to regular date
tmpDate = datetime.datetime.fromtimestamp(int(weather_data["Date"][0])).strftime('%Y-%m-%d')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Max Temp"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Max Temperature (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.ylim(30, 100)

plt.savefig("../output_data/MaxTmp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Humidity"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Humidity (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("../output_data/Humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Cloudiness"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Cloudiness (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.ylim(20, 100)

plt.savefig("../output_data/Cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Wind Speed"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Wind Speed (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.ylim(0, 30)

plt.savefig("../output_data/WindSpeed.png")

plt.show()
